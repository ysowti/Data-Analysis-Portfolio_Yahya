# %% [markdown]
# # Delivery Time Prediction Using XGB and Deep Learning

# %%
# !pip install -q git+https://github.com/tensorflow/docs

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
from sklearn.model_selection import GridSearchCV
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_absolute_error

# %%
val_ratio = 0.2

# %% [markdown]
# ## Loading Historical Data

# %%
df = pd.read_csv('historical_data.csv')

# %%
df.head()
# Out:
#    market_id           created_at actual_delivery_time  store_id  \
# 0        1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1        2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2        3.0  2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3        3.0  2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4        3.0  2015-02-15 02:40:36  2015-02-15 03:20:26      5477
#
#   store_primary_category  order_protocol  total_items  subtotal  \
# 0               american             1.0            4      3441
# 1                mexican             2.0            1      1900
# 2                    NaN             1.0            1      1900
# 3                    NaN             1.0            6      6900
# 4                    NaN             1.0            3      3900
#
#    num_distinct_items  min_item_price  max_item_price  total_onshift_dashers  \
# 0                   4             557            1239                   33.0
# 1                   1            1400            1400                    1.0
# 2                   1            1900            1900                    1.0
# 3                   5             600            1800                    1.0
# 4                   3            1100            1600                    6.0
#
#    total_busy_dashers  total_outstanding_orders  \
# 0                14.0                      21.0
# 1                 2.0                       2.0
# 2                 0.0                       0.0
# 3                 1.0                       2.0
# 4                 6.0                       9.0
#
#    estimated_order_place_duration  \
# 0                             446
# 1                             446
# 2                             446
# 3                             446
# 4                             446
#
#    estimated_store_to_consumer_driving_duration
# 0                                         861.0
# 1                                         690.0
# 2                                         690.0
# 3                                         289.0
# 4                                         650.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197428 entries, 0 to 197427
# Data columns (total 16 columns):
# market_id                                       196441 non-null float64
# created_at                                      197428 non-null object
# actual_delivery_time                            197421 non-null object
# store_id                                        197428 non-null int64
# store_primary_category                          192668 non-null object
# order_protocol                                  196433 non-null float64
# total_items                                     197428 non-null int64
# subtotal                                        197428 non-null int64
# num_distinct_items                              197428 non-null int64
# min_item_price                                  197428 non-null int64
# max_item_price                                  197428 non-null int64
# total_onshift_dashers                           181166 non-null float64
# total_busy_dashers                              181166 non-null float64
# total_outstanding_orders                        181166 non-null float64
# estimated_order_place_duration                  197428 non-null int64
# estimated_store_to_consumer_driving_duration    196902 non-null float64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 24.1+ MB

# %% [markdown]
# ## Preprocessing of Data and Feature Engineering

# %% [markdown]
# ### 1- Calculating Delivery Times and removing rows with null values for it

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# market_id                                         987
# actual_delivery_time                                7
# store_primary_category                           4760
# order_protocol                                    995
# total_onshift_dashers                           16262
# total_busy_dashers                              16262
# total_outstanding_orders                        16262
# estimated_store_to_consumer_driving_duration      526
# dtype: int64

# %%
df.dropna(subset=["actual_delivery_time"], inplace = True)

# %%
df[["created_at", "actual_delivery_time"]] = df[["created_at", "actual_delivery_time"]].apply(pd.to_datetime)

df["delivery_time"] = df.apply(lambda row: \
                               (row["actual_delivery_time"] - row["created_at"]).total_seconds(), \
                               axis = 1)

# %% [markdown]
# ### 2- Adding time related features

# %%
df['dayoftheweek'] = df['created_at'].apply(lambda x: x.date().isocalendar()[2])
df['hour'] = df['created_at'].apply(lambda x: x.hour)

# %% [markdown]
# ### 3- Studying Data stats and removing negative values and anomalous output based on that

# %%
stats = df.describe()
stats.transpose()
# Out:
#                                                  count         mean  \
# market_id                                     196434.0     2.978700
# store_id                                      197421.0  3530.581397
# order_protocol                                196426.0     2.882358
# total_items                                   197421.0     3.196367
# subtotal                                      197421.0  2682.326379
# num_distinct_items                            197421.0     2.670780
# min_item_price                                197421.0   686.224596
# max_item_price                                197421.0  1159.590444
# total_onshift_dashers                         181159.0    44.806866
# total_busy_dashers                            181159.0    41.738787
# total_outstanding_orders                      181159.0    58.047969
# estimated_order_place_duration                197421.0   308.560244
# estimated_store_to_consumer_driving_duration  196895.0   545.357089
# delivery_time                                 197421.0  2908.257374
# dayoftheweek                                  197421.0     4.218923
# hour                                          197421.0     8.467362
#
#                                                        std    min     25%  \
# market_id                                         1.524879    1.0     2.0
# store_id                                       2053.493429    1.0  1686.0
# order_protocol                                    1.503775    1.0     1.0
# total_items                                       2.666552    1.0     2.0
# subtotal                                       1823.106256    0.0  1400.0
# num_distinct_items                                1.630261    1.0     1.0
# min_item_price                                  522.044061  -86.0   299.0
# max_item_price                                  558.416236    0.0   800.0
# total_onshift_dashers                            34.525913   -4.0    17.0
# total_busy_dashers                               32.145163   -5.0    15.0
# total_outstanding_orders                         52.660056   -6.0    17.0
# estimated_order_place_duration                   90.139725    0.0   251.0
# estimated_store_to_consumer_driving_duration    219.353976    0.0   382.0
# delivery_time                                 19229.608945  101.0  2104.0
# dayoftheweek                                      2.045759    1.0     2.0
# hour                                              8.658781    0.0     2.0
#
#                                                  50%     75%        max
# market_id                                        3.0     4.0        6.0
# store_id                                      3592.0  5299.0     6987.0
# order_protocol                                   3.0     4.0        7.0
# total_items                                      3.0     4.0      411.0
# subtotal                                      2200.0  3395.0    27100.0
# num_distinct_items                               2.0     3.0       20.0
# min_item_price                                 595.0   949.0    14700.0
# max_item_price                                1095.0  1395.0    14700.0
# total_onshift_dashers                           37.0    65.0      171.0
# total_busy_dashers                              34.0    62.0      154.0
# total_outstanding_orders                        41.0    85.0      285.0
# estimated_order_place_duration                 251.0   446.0     2715.0
# estimated_store_to_consumer_driving_duration   544.0   702.0     2088.0
# delivery_time                                 2660.0  3381.0  8516859.0
# dayoftheweek                                     4.0     6.0        7.0
# hour                                             3.0    19.0       23.0

# %%
df[df['min_item_price'] < 0] = 0
df[df['total_outstanding_orders'] < 0] = 0
df[df['total_onshift_dashers'] < 0] = 0
df[df['total_busy_dashers'] < 0] = 0

# %%
df = df[df['delivery_time'] < 1e5]

# %%
stats = df.describe()
stats.transpose()
# Out:
#                                                  count         mean  \
# market_id                                     196431.0     2.977717
# store_id                                      197418.0  3529.020743
# order_protocol                                196423.0     2.881032
# total_items                                   197418.0     3.194278
# subtotal                                      197418.0  2681.126832
# num_distinct_items                            197418.0     2.669483
# min_item_price                                197418.0   685.908342
# max_item_price                                197418.0  1159.075211
# total_onshift_dashers                         181158.0    44.802195
# total_busy_dashers                            181158.0    41.734580
# total_outstanding_orders                      181158.0    58.044276
# estimated_order_place_duration                197418.0   308.399133
# estimated_store_to_consumer_driving_duration  196893.0   545.093985
# delivery_time                                 197418.0  2860.143492
# dayoftheweek                                  197418.0     4.216966
# hour                                          197418.0     8.461625
#
#                                                       std  min     25%  \
# market_id                                        1.525896  0.0     2.0
# store_id                                      2054.438894  0.0  1686.0
# order_protocol                                   1.504687  0.0     1.0
# total_items                                      2.664548  0.0     2.0
# subtotal                                      1823.729805  0.0  1400.0
# num_distinct_items                               1.630846  0.0     1.0
# min_item_price                                 522.061122  0.0   299.0
# max_item_price                                 558.828165  0.0   800.0
# total_onshift_dashers                           34.530033  0.0    17.0
# total_busy_dashers                              32.148906  0.0    15.0
# total_outstanding_orders                        52.662558  0.0    17.0
# estimated_order_place_duration                  90.363603  0.0   251.0
# estimated_store_to_consumer_driving_duration   219.622033  0.0   382.0
# delivery_time                                 1165.486568  0.0  2103.0
# dayoftheweek                                     2.047343  0.0     2.0
# hour                                             8.658376  0.0     2.0
#
#                                                  50%     75%      max
# market_id                                        3.0     4.0      6.0
# store_id                                      3586.0  5299.0   6987.0
# order_protocol                                   3.0     4.0      7.0
# total_items                                      3.0     4.0    411.0
# subtotal                                      2200.0  3395.0  27100.0
# num_distinct_items                               2.0     3.0     20.0
# min_item_price                                 595.0   949.0  14700.0
# max_item_price                                1095.0  1395.0  14700.0
# total_onshift_dashers                           37.0    65.0    171.0
# total_busy_dashers                              34.0    62.0    154.0
# total_outstanding_orders                        41.0    85.0    285.0
# estimated_order_place_duration                 251.0   446.0   2715.0
# estimated_store_to_consumer_driving_duration   543.0   702.0   2088.0
# delivery_time                                 2659.0  3381.0  57032.0
# dayoftheweek                                     4.0     6.0      7.0
# hour                                             3.0    19.0     23.0

# %% [markdown]
# ### 4- Filling existing null values in columns

# %%
df['store_primary_category'].fillna('Unknown', inplace = True)

# %%
df['order_protocol'].unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan,  5.,  0.,  6.,  7.])

# %%
df['market_id'].unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan,  5.,  6.,  0.])

# %%
df['order_protocol'].fillna(np.float64(-1), inplace = True)
df['market_id'].fillna(np.float64(-1), inplace = True)

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
mean_columns = ['total_onshift_dashers','total_busy_dashers','total_outstanding_orders','estimated_store_to_consumer_driving_duration']
imp_mean.fit(df[mean_columns])
df[mean_columns] = imp_mean.transform(df[mean_columns])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197418 entries, 0 to 197427
# Data columns (total 19 columns):
# market_id                                       197418 non-null float64
# created_at                                      197418 non-null object
# actual_delivery_time                            197418 non-null object
# store_id                                        197418 non-null int64
# store_primary_category                          197418 non-null object
# order_protocol                                  197418 non-null float64
# total_items                                     197418 non-null int64
# subtotal                                        197418 non-null int64
# num_distinct_items                              197418 non-null int64
# min_item_price                                  197418 non-null int64
# max_item_price                                  197418 non-null int64
# total_onshift_dashers                           197418 non-null float64
# total_busy_dashers                              197418 non-null float64
# total_outstanding_orders                        197418 non-null float64
# estimated_order_place_duration                  197418 non-null int64
# estimated_store_to_consumer_driving_duration    197418 non-null float64
# delivery_time                                   197418 non-null float64
# dayoftheweek                                    197418 non-null int64
# hour                                            197418 non-null int64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 30.1+ MB

# %% [markdown]
# ### 5- Creating a new feature for available dashers that are not busy

# %%
df['total_not_busy_dashers'] = df.apply(lambda row: \
                                         max(row['total_onshift_dashers'] - row['total_busy_dashers'], 0), \
                                         axis = 1)

# %% [markdown]
# ### 6- Converting ordinal columns to string

# %%
df[['market_id', 'store_id', 'order_protocol', 'dayoftheweek', 'hour']] = \
df[['market_id', 'store_id', 'order_protocol', 'dayoftheweek', 'hour']].astype('str')

# %% [markdown]
# ### 7- Studying relationship between target value and numerical features

# %%
correlation = np.abs(df.corr()['delivery_time']).sort_values(ascending=False)
print(correlation)
# Out:
# delivery_time                                   1.000000
# estimated_store_to_consumer_driving_duration    0.225323
# subtotal                                        0.205618
# total_outstanding_orders                        0.167564
# num_distinct_items                              0.149428
# max_item_price                                  0.128281
# total_items                                     0.112613
# estimated_order_place_duration                  0.100940
# total_busy_dashers                              0.084736
# total_not_busy_dashers                          0.070697
# total_onshift_dashers                           0.066297
# min_item_price                                  0.016374
# Name: delivery_time, dtype: float64

# %%
num_cols=list(df.select_dtypes(exclude=['object']).columns)
num_cols
# Out:
# ['total_items',
#  'subtotal',
#  'num_distinct_items',
#  'min_item_price',
#  'max_item_price',
#  'total_onshift_dashers',
#  'total_busy_dashers',
#  'total_outstanding_orders',
#  'estimated_order_place_duration',
#  'estimated_store_to_consumer_driving_duration',
#  'delivery_time',
#  'total_not_busy_dashers']

# %%
def plot_rel(num_cols):
    plt.figure(figsize = (10, 50))
    for i, col in enumerate(num_cols):
        ax = plt.subplot(len(num_cols), 1, i + 1)
        sns.scatterplot(x=df[col], y=df["delivery_time"], ax = ax);
        
plot_rel(num_cols)

# %% [markdown]
# ### 8- Removing some anomalies from numerical features and target

# %%
df = df[df['delivery_time'] < 3e4]

# %%
df = df[df['max_item_price'] < 14000]
df = df[df['total_items'] < 200]

# %%
df.drop('total_onshift_dashers', 1, inplace = True)

# %% [markdown]
# ### 9- Visualizing relationship between categorical variables and the target value

# %%
def cat_plot(category, plot_type):
    sns.catplot(
        data=df,
        x=category,
        y='delivery_time',
        kind=plot_type,
        height=7, # make the plot 5 units high
        aspect=3
    )
    
def hor_cat_plot(category, plot_type):
    sns.catplot(
        data=df,
        y=category,
        x='delivery_time',
        kind=plot_type,
        height=10,
        aspect=2,
        orient="h"
    )

# %%
hor_cat_plot('store_primary_category', 'box')

# %%
cat_plot('market_id', 'box')

# %%
cat_plot('order_protocol', 'box')

# %%
cat_plot('dayoftheweek', 'box')

# %%
cat_plot('hour', 'box')

# %% [markdown]
# ### 10- Dropping non feature columns and shuffling the train data

# %%
df = sklearn.utils.shuffle(df)

# %%
df.drop(columns = ['created_at', 'actual_delivery_time', 'store_id'], inplace = True)
df.head(10)
# Out:
#        market_id store_primary_category order_protocol  total_items  subtotal  \
# 124573       2.0                mexican            5.0            5      3950
# 118404       3.0      convenience-store            4.0            1       239
# 184973       2.0               american            1.0            2      1868
# 67865        2.0                  asian            3.0            3      4385
# 8973         2.0                  pizza            2.0            1      1399
# 68205        5.0                 korean            5.0            2      3800
# 49329        2.0                 burger            5.0            3      1325
# 50562        3.0                mexican            1.0            3      5590
# 91553        5.0               american            1.0            1      1099
# 94927        6.0                Unknown            5.0            3      3100
#
#         num_distinct_items  min_item_price  max_item_price  \
# 124573                   4             190            1515
# 118404                   1             239             239
# 184973                   2             659            1209
# 67865                    3            1195            1795
# 8973                     1             699             699
# 68205                    2            1600            2200
# 49329                    3             275             550
# 50562                    3            1695            2000
# 91553                    1            1099            1099
# 94927                    3             600            1300
#
#         total_busy_dashers  total_outstanding_orders  \
# 124573            59.00000                 90.000000
# 118404             3.00000                  4.000000
# 184973            43.00000                 31.000000
# 67865             10.00000                  9.000000
# 8973              49.00000                 54.000000
# 68205             19.00000                 27.000000
# 49329            115.00000                164.000000
# 50562              1.00000                  1.000000
# 91553              9.00000                 10.000000
# 94927             41.73458                 58.044276
#
#         estimated_order_place_duration  \
# 124573                             251
# 118404                             251
# 184973                             446
# 67865                              251
# 8973                               251
# 68205                              251
# 49329                              251
# 50562                              446
# 91553                              446
# 94927                              251
#
#         estimated_store_to_consumer_driving_duration  delivery_time  \
# 124573                                         535.0         1973.0
# 118404                                         285.0         2545.0
# 184973                                         769.0         3429.0
# 67865                                          751.0         2263.0
# 8973                                           453.0         2315.0
# 68205                                          274.0         2642.0
# 49329                                          867.0         3119.0
# 50562                                          293.0         2883.0
# 91553                                          515.0         2197.0
# 94927                                          477.0         5159.0
#
#        dayoftheweek hour  total_not_busy_dashers
# 124573            4    3                1.000000
# 118404            5   16                0.000000
# 184973            7   20                0.000000
# 67865             2   18                4.000000
# 8973              5   19                4.000000
# 68205             5    2                3.000000
# 49329             7    2                0.000000
# 50562             7   23                5.000000
# 91553             6   19                7.000000
# 94927             4    3                3.067615

# %% [markdown]
# ## Preparing Data for Machine Learning

# %% [markdown]
# ### 1- Splitting target value and feature data frames

# %%
df_target = df[['delivery_time']]
df_feature = df.drop('delivery_time', 1)

# %%
num_cols=list(df_feature.select_dtypes(exclude=['object']).columns)
num_cols
# Out:
# ['total_items',
#  'subtotal',
#  'num_distinct_items',
#  'min_item_price',
#  'max_item_price',
#  'total_busy_dashers',
#  'total_outstanding_orders',
#  'estimated_order_place_duration',
#  'estimated_store_to_consumer_driving_duration',
#  'total_not_busy_dashers']

# %% [markdown]
# ### 2- One-hot encoding of categorical and ordinal features

# %%
df_feature = pd.get_dummies(df_feature)
df_feature.columns[90:]
# Out:
# Index(['store_primary_category_turkish', 'store_primary_category_vegan',
#        'store_primary_category_vegetarian',
#        'store_primary_category_vietnamese', 'order_protocol_-1.0',
#        'order_protocol_0.0', 'order_protocol_1.0', 'order_protocol_2.0',
#        'order_protocol_3.0', 'order_protocol_4.0', 'order_protocol_5.0',
#        'order_protocol_6.0', 'order_protocol_7.0', 'dayoftheweek_0',
#        'dayoftheweek_1', 'dayoftheweek_2', 'dayoftheweek_3', 'dayoftheweek_4',
#        'dayoftheweek_5', 'dayoftheweek_6', 'dayoftheweek_7', 'hour_0',
#        'hour_1', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_2', 'hour_20', 'hour_21', 'hour_22', 'hour_23',
#        'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7'],
#       dtype='object')

# %%
train_columns = df_feature.columns
print(f"Number of columns for train set is {len(train_columns)}")
# Out:
# Number of columns for train set is 129

# %% [markdown]
# ### 3- Splitting dataset to train and validation set

# %%
train_samples = int(np.ceil((1 - val_ratio) * df_feature.shape[0]))
print(f"Number of train samples is {train_samples}")
# Out:
# Number of train samples is 157924

# %%
df_train = df_feature[:train_samples]
train_target = df_target[:train_samples]
df_val = df_feature[train_samples:]
val_target = df_target[train_samples:]

# %% [markdown]
# ### 4- Normalizing numerical features for train and validation sets

# %%
num_train_features = df_train[num_cols]
scaler = StandardScaler().fit(num_train_features.values)
scaled_train_features = scaler.transform(num_train_features.values)
df_train[num_cols] = scaled_train_features
# Out:
# /Users/yahya/anaconda/envs/forecasting/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/yahya/anaconda/envs/forecasting/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
num_val_features = df_val[num_cols]
scaled_val_features = scaler.transform(num_val_features.values)
df_val[num_cols] = scaled_val_features
# Out:
# /Users/yahya/anaconda/envs/forecasting/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yahya/anaconda/envs/forecasting/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
X_train = df_train.values
y_train = train_target.values
X_val = df_val.values
y_val = val_target.values

# %%
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (157924, 129) (157924, 1) (39481, 129) (39481, 1)

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ### 1 - Training and evaluation of dense neural network

# %%
def build_dense_model(train_data, num_layers, nodes, dropout_ratio, learning_rate):
    model = tf.keras.Sequential()
    if num_layers >= 2:
        model.add(layers.Dense(nodes, activation='relu', input_shape = (train_data.shape[1],)))
        model.add(layers.Dropout(dropout_ratio))
    if num_layers == 3:
        model.add(layers.Dense(nodes//2, activation='relu'))
        model.add(layers.Dropout(dropout_ratio))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(dropout_ratio))
    model.add(layers.Dense(1))
    optimizer = keras.optimizers.Adam(learning_rate)
    model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
    return model

# %%
earlystop_callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1000,  patience=5)

# %%
dense_model = build_dense_model(X_train, 3, 512, 0, 0.001)
dense_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 512)               66560
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 214,401
# Trainable params: 214,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = dense_model.fit(X_train, y_train, epochs=100,
                          batch_size =512,
                          callbacks=[earlystop_callback],
                          validation_data=(X_val, y_val))
# Out:
# Train on 157924 samples, validate on 39481 samples
# Epoch 1/100
# 157924/157924 [==============================] - 4s 24us/sample - loss: 2388023.7591 - mae: 1079.5554 - val_loss: 939798.3675 - val_mae: 691.9153
# Epoch 2/100
# 157924/157924 [==============================] - 3s 19us/sample - loss: 944075.5670 - mae: 683.6531 - val_loss: 924993.7026 - val_mae: 679.6165
# Epoch 3/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 936059.5746 - mae: 680.3317 - val_loss: 919481.1292 - val_mae: 676.5516
# Epoch 4/100
# 157924/157924 [==============================] - 3s 19us/sample - loss: 927974.5833 - mae: 676.8207 - val_loss: 911484.1837 - val_mae: 669.2292
# Epoch 5/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 918169.6409 - mae: 672.1688 - val_loss: 903619.4386 - val_mae: 663.2374
# Epoch 6/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 909159.3774 - mae: 667.7901 - val_loss: 891381.7851 - val_mae: 667.5333
# Epoch 7/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 900635.9115 - mae: 664.1369 - val_loss: 887611.1055 - val_mae: 671.5859
# Epoch 8/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 893517.8342 - mae: 661.1412 - val_loss: 879050.2398 - val_mae: 656.8315
# Epoch 9/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 887219.1336 - mae: 658.0714 - val_loss: 872907.2694 - val_mae: 658.2045
# Epoch 10/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 881117.4629 - mae: 655.6373 - val_loss: 869725.8067 - val_mae: 658.8418
# Epoch 11/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 875656.0693 - mae: 653.3261 - val_loss: 866610.8607 - val_mae: 646.6451
# Epoch 12/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 871337.7135 - mae: 651.2369 - val_loss: 863388.5757 - val_mae: 659.1721
# Epoch 13/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 867048.6300 - mae: 649.5774 - val_loss: 858781.1773 - val_mae: 655.5829
# Epoch 14/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 864054.1340 - mae: 648.3164 - val_loss: 856069.8343 - val_mae: 649.6443
# Epoch 15/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 860010.6197 - mae: 646.4393 - val_loss: 855059.1474 - val_mae: 652.3378
# Epoch 16/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 857615.9201 - mae: 645.6998 - val_loss: 852754.1633 - val_mae: 647.7311
# Epoch 17/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 855034.4755 - mae: 644.5540 - val_loss: 857514.1256 - val_mae: 640.1129
# Epoch 18/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 852112.2551 - mae: 643.4669 - val_loss: 855539.1723 - val_mae: 639.9781
# Epoch 19/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 850786.8368 - mae: 643.0435 - val_loss: 849582.8530 - val_mae: 645.5062
# Epoch 20/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 846348.1669 - mae: 641.0776 - val_loss: 848423.7564 - val_mae: 642.7658
# Epoch 21/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 843982.1161 - mae: 640.2015 - val_loss: 845338.1975 - val_mae: 643.2505
# Epoch 22/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 841967.2621 - mae: 639.1263 - val_loss: 845933.7520 - val_mae: 647.5650
# Epoch 23/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 839558.9758 - mae: 638.3926 - val_loss: 848516.3127 - val_mae: 647.3280
# Epoch 24/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 837360.3965 - mae: 637.6597 - val_loss: 843928.4914 - val_mae: 644.1110
# Epoch 25/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 835450.0035 - mae: 636.7695 - val_loss: 843002.3017 - val_mae: 642.6180
# Epoch 26/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 834113.5055 - mae: 635.9991 - val_loss: 842418.7997 - val_mae: 640.7420
# Epoch 27/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 831210.1297 - mae: 634.7242 - val_loss: 842325.5823 - val_mae: 638.6913
# Epoch 28/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 828510.7551 - mae: 633.6996 - val_loss: 847358.3150 - val_mae: 657.8317
# Epoch 29/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 826160.0770 - mae: 633.0435 - val_loss: 841990.3345 - val_mae: 636.9660
# Epoch 30/100
# 157924/157924 [==============================] - 3s 20us/sample - loss: 825334.4629 - mae: 632.4332 - val_loss: 842397.4011 - val_mae: 647.0795
# Epoch 31/100
# 157924/157924 [==============================] - 3s 21us/sample - loss: 822159.2590 - mae: 631.1860 - val_loss: 843660.5717 - val_mae: 636.6539

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std = 2)
plotter.plot({'Basic': history}, metric = "mae")
plt.ylim([600, 800])
plt.ylabel('MAE [delivery time]')
# Out:
# Text(0, 0.5, 'MAE [delivery time]')

# %%
dense_model = build_dense_model(X_train, 3, 512, 0.1, 0.001)
dense_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 512)               66560
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 214,401
# Trainable params: 214,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = dense_model.fit(X_train, y_train, epochs=100,
                          batch_size = 512,
                          callbacks=[earlystop_callback],
                          validation_data=(X_val, y_val))
# Out:
# Train on 157924 samples, validate on 39481 samples
# Epoch 1/100
# 157924/157924 [==============================] - 8s 50us/sample - loss: 2323677.7206 - mae: 1069.3594 - val_loss: 939509.9772 - val_mae: 680.4776
# Epoch 2/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 982288.6532 - mae: 698.6179 - val_loss: 925757.4408 - val_mae: 678.3352
# Epoch 3/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 970276.7887 - mae: 694.5638 - val_loss: 917874.5729 - val_mae: 682.7825
# Epoch 4/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 958475.0561 - mae: 689.2766 - val_loss: 909534.1996 - val_mae: 667.1577
# Epoch 5/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 951165.7882 - mae: 685.8619 - val_loss: 898708.4934 - val_mae: 668.9851
# Epoch 6/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 939782.9816 - mae: 680.9118 - val_loss: 894844.5986 - val_mae: 656.9936
# Epoch 7/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 933677.2222 - mae: 677.5115 - val_loss: 886820.1861 - val_mae: 655.8237
# Epoch 8/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 926324.4232 - mae: 674.8984 - val_loss: 880164.5698 - val_mae: 651.4951
# Epoch 9/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 921382.5304 - mae: 672.1271 - val_loss: 873813.7768 - val_mae: 659.1955
# Epoch 10/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 912851.9223 - mae: 669.1035 - val_loss: 868049.2088 - val_mae: 651.0846
# Epoch 11/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 912158.4043 - mae: 668.6321 - val_loss: 871182.8728 - val_mae: 644.8937
# Epoch 12/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 905962.0522 - mae: 665.9099 - val_loss: 861426.0202 - val_mae: 650.5946
# Epoch 13/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 901894.1387 - mae: 664.2169 - val_loss: 861488.6985 - val_mae: 645.7410
# Epoch 14/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 899117.7322 - mae: 663.1563 - val_loss: 858519.2611 - val_mae: 647.3900
# Epoch 15/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 896864.3617 - mae: 663.1653 - val_loss: 861981.2048 - val_mae: 641.7875
# Epoch 16/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 892844.8668 - mae: 661.1191 - val_loss: 856335.0523 - val_mae: 645.4596
# Epoch 17/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 889509.5152 - mae: 660.1718 - val_loss: 854380.0490 - val_mae: 644.5757
# Epoch 18/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 890684.4808 - mae: 659.7266 - val_loss: 852814.0963 - val_mae: 645.8513
# Epoch 19/100
# 157924/157924 [==============================] - 8s 48us/sample - loss: 888849.7118 - mae: 659.5068 - val_loss: 851479.4250 - val_mae: 651.2522
# Epoch 20/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 884841.9254 - mae: 657.9384 - val_loss: 851342.7995 - val_mae: 645.2797
# Epoch 21/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 882270.5291 - mae: 657.5586 - val_loss: 855376.1350 - val_mae: 637.5963
# Epoch 22/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 883773.6440 - mae: 657.5194 - val_loss: 851222.7581 - val_mae: 652.3479
# Epoch 23/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 880372.5047 - mae: 656.2858 - val_loss: 848852.2777 - val_mae: 645.9861
# Epoch 24/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 878282.0209 - mae: 655.4626 - val_loss: 849789.9261 - val_mae: 637.5156
# Epoch 25/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 877901.3246 - mae: 655.2086 - val_loss: 851918.0652 - val_mae: 658.9997
# Epoch 26/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 877749.1914 - mae: 655.0215 - val_loss: 845232.1439 - val_mae: 644.2621
# Epoch 27/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 873460.9533 - mae: 653.5667 - val_loss: 847647.9286 - val_mae: 654.6678
# Epoch 28/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 873860.6267 - mae: 653.4903 - val_loss: 846718.9980 - val_mae: 644.6261
# Epoch 29/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 871245.6030 - mae: 652.7462 - val_loss: 842523.3557 - val_mae: 640.9331
# Epoch 30/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 871285.5225 - mae: 652.2510 - val_loss: 842929.3624 - val_mae: 642.3776
# Epoch 31/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 868367.8924 - mae: 651.4962 - val_loss: 842207.3752 - val_mae: 645.1135
# Epoch 32/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 866698.3400 - mae: 651.2806 - val_loss: 848319.8552 - val_mae: 659.2279
# Epoch 33/100
# 157924/157924 [==============================] - 7s 45us/sample - loss: 867646.1148 - mae: 651.2482 - val_loss: 844170.9481 - val_mae: 637.5068
# Epoch 34/100
# 157924/157924 [==============================] - 7s 46us/sample - loss: 865374.5358 - mae: 650.1326 - val_loss: 841949.8642 - val_mae: 637.4949

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mae")
plt.ylim([600, 800])
plt.ylabel('MAE [delivery time]')
# Out:
# Text(0, 0.5, 'MAE [delivery time]')

# %%
_, train_mae = dense_model.evaluate(X_train, y_train, verbose=0)
_, val_mae = dense_model.evaluate(X_val, y_val, verbose=0)

# %%
print('For Dense NN model Validation MAE: %.3f' % (val_mae))
# Out:
# For Dense NN model Validation MAE: 637.495

# %% [markdown]
# ### 2- Hyper-parameter selection, Training and evaluation of XGBoost Regressor model

# %%
xgb = XGBRegressor()
parameters = {'nthread':[4],
              'objective':['reg:linear'],
              'learning_rate': [0.05, 0.07],
              'max_depth': [4, 6],
              'min_child_weight': [2, 4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500, 700],
             }

# %%
xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True
                       )

# %%
xgb_grid.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  32 out of  32 | elapsed: 43.0min finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=5,
#              param_grid={'colsample_bytree': [0.7],
#                          'learning_rate': [0.05, 0.07], 'max_depth': [4, 6],
#                          'min_child_weight': [2, 4], 'n_estimators': [500, 700],
#                          'nthread': [4], 'objective': ['reg:linear'],
#                          'silent': [1], 'subsample': [0.7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=True)

# %%
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
xgb_model = xgb_grid.best_estimator_
print("Best XGB estimator:\n{}".format(xgb_model))
# Out:
# 0.325561112270313
# {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 6, 'min_child_weight': 4, 'n_estimators': 700, 'nthread': 4, 'objective': 'reg:linear', 'silent': 1, 'subsample': 0.7}
# Best XGB estimator:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=4, missing=None, n_estimators=700,
#              n_jobs=1, nthread=4, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=1,
#              subsample=0.7, verbosity=1)

# %% [markdown]
# ### 3- XGBoost Regressor is selected as the best model for prediction

# %%
y_pred = xgb_grid.predict(X_val)
xgb_mae = mean_absolute_error(y_val, y_pred)
print('For XGB model Validation MAE: %.3f'%(xgb_mae))
# Out:
# For XGB model Validation MAE: 641.128

# %% [markdown]
# ## Prediction on the Test Dataset

# %% [markdown]
# ### 1- Preprocessing of the test dataset

# %%
df_test_original = pd.read_csv('predict_data.csv')
df_test = df_test_original.copy()
df_test.head()
# Out:
#    market_id           created_at  store_id store_primary_category  \
# 0        3.0  2015-02-25 02:22:30      5477                    NaN
# 1        3.0  2015-02-25 01:14:19      5477                    NaN
# 2        4.0  2015-02-22 02:27:44      5477                   thai
# 3        3.0  2015-02-25 01:32:39      5477                    NaN
# 4        1.0  2015-02-24 05:20:45      2841                italian
#
#    order_protocol  total_items  subtotal  num_distinct_items  min_item_price  \
# 0             1.0            5      7500                   4             800
# 1             1.0            5      7100                   4             800
# 2             1.0            4      4500                   2             750
# 3             1.0            1      1700                   1            1400
# 4             1.0            2      3150                   2            1525
#
#    max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0            1800                    4.0                 4.0
# 1            1500                    4.0                 1.0
# 2            1500                    9.0                 7.0
# 3            1400                    3.0                 3.0
# 4            1625                    4.0                 4.0
#
#    total_outstanding_orders  estimated_order_place_duration  \
# 0                       4.0                             446
# 1                       1.0                             446
# 2                       6.0                             446
# 3                       3.0                             446
# 4                       4.0                             446
#
#    estimated_store_to_consumer_driving_duration  delivery_id platform
# 0                                         670.0       194096  android
# 1                                         446.0       236895    other
# 2                                         504.0       190868  android
# 3                                         687.0       183076      ios
# 4                                         528.0       186200  android

# %%
df_test.drop(columns=['delivery_id', 'platform'], inplace = True)

# %%
df_test[["created_at"]] = df_test[["created_at"]].apply(pd.to_datetime)
df_test['dayoftheweek'] = df_test['created_at'].apply(lambda x: x.date().isocalendar()[2])
df_test['hour'] = df_test['created_at'].apply(lambda x: x.hour)

# %%
df_test[df_test['min_item_price'] < 0] = 0
df_test[df_test['total_outstanding_orders'] < 0] = 0
df_test[df_test['total_onshift_dashers'] < 0] = 0
df_test[df_test['total_busy_dashers'] < 0] = 0

# %%
null_columns=df_test.columns[df_test.isnull().any()]
df_test[null_columns].isnull().sum()
# Out:
# market_id                                        250
# store_primary_category                          1342
# order_protocol                                   283
# total_onshift_dashers                           4631
# total_busy_dashers                              4631
# total_outstanding_orders                        4631
# estimated_store_to_consumer_driving_duration      11
# dtype: int64

# %%
df_test['store_primary_category'].fillna('Unknown', inplace = True)

# %%
df_test['order_protocol'].fillna(np.float64(-1), inplace = True)
df_test['market_id'].fillna(np.float64(-1), inplace = True)

# %%
df_test[mean_columns] = imp_mean.transform(df_test[mean_columns])

# %%
df_test[null_columns].isnull().sum()
# Out:
# market_id                                       0
# store_primary_category                          0
# order_protocol                                  0
# total_onshift_dashers                           0
# total_busy_dashers                              0
# total_outstanding_orders                        0
# estimated_store_to_consumer_driving_duration    0
# dtype: int64

# %%
df_test.head()
# Out:
#    market_id           created_at  store_id store_primary_category  \
# 0        3.0  2015-02-25 02:22:30      5477                Unknown
# 1        3.0  2015-02-25 01:14:19      5477                Unknown
# 2        4.0  2015-02-22 02:27:44      5477                   thai
# 3        3.0  2015-02-25 01:32:39      5477                Unknown
# 4        1.0  2015-02-24 05:20:45      2841                italian
#
#    order_protocol  total_items  subtotal  num_distinct_items  min_item_price  \
# 0             1.0            5      7500                   4             800
# 1             1.0            5      7100                   4             800
# 2             1.0            4      4500                   2             750
# 3             1.0            1      1700                   1            1400
# 4             1.0            2      3150                   2            1525
#
#    max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0            1800                    4.0                 4.0
# 1            1500                    4.0                 1.0
# 2            1500                    9.0                 7.0
# 3            1400                    3.0                 3.0
# 4            1625                    4.0                 4.0
#
#    total_outstanding_orders  estimated_order_place_duration  \
# 0                       4.0                             446
# 1                       1.0                             446
# 2                       6.0                             446
# 3                       3.0                             446
# 4                       4.0                             446
#
#    estimated_store_to_consumer_driving_duration  dayoftheweek  hour
# 0                                         670.0             3     2
# 1                                         446.0             3     1
# 2                                         504.0             7     2
# 3                                         687.0             3     1
# 4                                         528.0             2     5

# %% [markdown]
# ### 2- One-hot encoding of test set

# %%
df_test[['market_id', 'store_id', 'order_protocol', 'dayoftheweek', 'hour']] = \
df_test[['market_id', 'store_id', 'order_protocol', 'dayoftheweek', 'hour']].astype('str')

# %%
df_test.drop(columns = ['created_at', 'store_id', 'total_onshift_dashers'], inplace = True)

# %%
df_test = pd.get_dummies(df_test)

# %%
missing_cols = [col for col in train_columns if col not in df_test.columns]
print(f"Missing columns from test set: {missing_cols}")
# Out:
# Missing columns from test set: ['total_not_busy_dashers', 'store_primary_category_belgian', 'store_primary_category_chocolate', 'store_primary_category_lebanese']

# %%
df_test = df_test.reindex(columns=df_test.columns.tolist() + missing_cols)   # add empty cols
df_test[missing_cols] = 0

# %%
print(f"Number of columns for the test set is {len(df_test.columns)}")
# Out:
# Number of columns for the test set is 129

# %% [markdown]
# ### 3- Normalizing test set based on stats from all of training set

# %%
num_features = df_feature[num_cols]
full_scaler = StandardScaler().fit(num_features.values)
scaled_features = full_scaler.transform(num_features.values)
df_feature[num_cols] = scaled_features

# %%
num_test_features = df_test[num_cols]
scaled_test_features = full_scaler.transform(num_test_features.values)
df_test[num_cols] = scaled_test_features

# %% [markdown]
# ### 3- Training best selected model on all of training set

# %%
X_train = df_feature.values
y_train = df_target.values
X_test = df_test.values

# %%
print(X_train.shape, y_train.shape, X_test.shape)
# Out:
# (197405, 129) (197405, 1) (54778, 129)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=4, missing=None, n_estimators=700,
#              n_jobs=1, nthread=4, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=1,
#              subsample=0.7, verbosity=1)

# %% [markdown]
# ### 4- Generating and storing prediction on test set

# %%
y_pred = xgb_model.predict(X_test)

# %%
y_pred_rounded = np.round_(y_pred)
df_test_original['delivery_time'] = y_pred_rounded

# %%
df_test_original.to_csv (r'yahya_delivery_time_prediction_ver2.csv', index = False, header=True)
